# %% [markdown]
# # 00 — Introduction to istSOS4 and SensorThings API
#
# **Goal:** understand the workshop scenario and verify that the local istSOS4 service is reachable.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
DATA = ROOT / 'data'

from sta_client import BASE_URL, get_json, post_entity, post_observation
BASE_URL

# %% [markdown]
# ## Exercise 0.1 — Check the service
# Run the next cell. If the service is unavailable, start the Docker stack before continuing.

# %%
import requests
r = requests.get(BASE_URL, timeout=10)
print(r.status_code)
print(r.text[:500])

# %% [markdown]
# ## Exercise 0.2 — Inspect available collections
# Try to identify the SensorThings collections exposed by the service.

# %%
# TODO: print the available collections returned by the service
# HINT: the landing page is JSON and usually contains a 'value' list
landing = requests.get(BASE_URL, timeout=10).json()
landing

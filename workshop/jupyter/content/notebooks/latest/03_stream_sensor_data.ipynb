# %% [markdown]
# # 03 — Simulate real-time sensor data upload
#
# **Goal:** simulate a sensor sending observations periodically.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
DATA = ROOT / 'data'

from sta_client import BASE_URL, get_json, post_entity, post_observation
BASE_URL

from data_generators import temperature_stream

# %% [markdown]
# ## Exercise 3.1 — Preview simulated values

# %%
stream = list(temperature_stream(n=5, interval_seconds=1))
stream

# %% [markdown]
# ## Exercise 3.2 — Send values to istSOS4

# %%
TEMPERATURE_DATASTREAM_ID = None  # TODO

# TODO: uncomment after setting the datastream ID
# sent = []
# for obs in temperature_stream(n=10, interval_seconds=1):
#     sent.append(post_observation(TEMPERATURE_DATASTREAM_ID, obs['phenomenonTime'], obs['result'], {'source': 'simulator'}))
# sent

# %% [markdown]
# ## Exercise 3.3 — Query the last observations

# %%
# TODO: retrieve most recent observations ordered by phenomenonTime desc
# get_json(f'Datastreams({TEMPERATURE_DATASTREAM_ID})/Observations', params={'$orderby':'phenomenonTime desc', '$top':10})

# %% [markdown]
# # 05 — Query, filter and visualize SensorThings data
#
# **Goal:** use SensorThings query options and create a plot.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
DATA = ROOT / 'data'

from sta_client import BASE_URL, get_json, post_entity, post_observation
BASE_URL

# %% [markdown]
# ## Exercise 5.1 — Query with `$filter`, `$select`, `$orderby`, `$top`

# %%
TEMPERATURE_DATASTREAM_ID = None  # TODO
params = {
    '$select': 'phenomenonTime,result',
    '$orderby': 'phenomenonTime asc',
    '$top': 100,
}
# data = get_json(f'Datastreams({TEMPERATURE_DATASTREAM_ID})/Observations', params=params)
# data

# %% [markdown]
# ## Exercise 5.2 — Convert response to DataFrame and plot

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# values = data['value']
# df = pd.DataFrame(values)
# df['phenomenonTime'] = pd.to_datetime(df['phenomenonTime'])
# df.plot(x='phenomenonTime', y='result', figsize=(10,4), title='Air temperature')

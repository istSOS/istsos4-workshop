# %% [markdown]
# # 06 — Reproducibility and temporal access
#
# **Goal:** demonstrate why version-aware access is useful for dynamic environmental data.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
DATA = ROOT / 'data'

from sta_client import BASE_URL, get_json, post_entity, post_observation
BASE_URL

# %% [markdown]
# ## Exercise 6.1 — Correction scenario
# Imagine that a suspicious value was corrected after QA. Record the original value, update it, and compare current vs historical access if the deployed istSOS4 instance supports temporal/version query parameters.

# %%
OBSERVATION_ID = None  # TODO: choose an existing observation

# Current state
# current = get_json(f'Observations({OBSERVATION_ID})')
# current

# %% [markdown]
# ## Exercise 6.2 — Temporal query examples
# Depending on the istSOS4 deployment, try parameters such as `$as_of` or history ranges.

# %%
# Example only: adapt to the version-aware query syntax enabled in your instance
# get_json(f'Observations({OBSERVATION_ID})', params={'$as_of':'2026-05-01T12:00:00Z'})

# Example history query
# get_json(f'Observations({OBSERVATION_ID})', params={'$expand':'Commit', '$from_to':'2026-05-01T00:00:00Z/2026-05-02T00:00:00Z'})

# %% [markdown]
# ## Reflection
# Write 5–8 lines explaining why reproducibility is difficult when web-service data change over time, and how temporal access helps.

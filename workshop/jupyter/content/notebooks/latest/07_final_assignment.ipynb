# %% [markdown]
# # 07 — Final assignment
#
# Create a small end-to-end SensorThings workflow.

# %% [markdown]
# ## Task
#
# 1. Create a new `Thing` representing a monitoring station.
# 2. Add at least one `Location`.
# 3. Create two `ObservedProperties`, two `Sensors` and two `Datastreams`.
# 4. Load at least 20 historical observations from one file.
# 5. Simulate at least 10 real-time observations.
# 6. Query a time interval and produce one plot.
# 7. Explain in 5–8 lines how you would handle corrections and reproducibility.

# %%
# Use this notebook as your workspace.
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
DATA = ROOT / 'data'
from sta_client import *
